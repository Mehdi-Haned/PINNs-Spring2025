# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import matplotlib.ticker as ticker
torch.manual_seed(125)

# %%
def sin(x):
    if isinstance(x, torch.Tensor):
        return torch.sin(x)
    else:
        return 

def cos(x):
    if isinstance(x, torch.Tensor):
        return torch.cos(x)
    else:
        return np.cos(x)

# %% [markdown]
# ## Generate training data

# %%
X0 = [1, 0]
w0 = 2*np.pi*1

# %%
# Parameters and initial conditions

# time domain
ti = 0
tf = 3
N  = 10_000

t = torch.linspace(ti, tf, N).view(-1,1)

# Numerical Solution

def ODE(X, t):
    dXdt = [X[1], -(w0**2)*np.sin(X[0])]
    return dXdt

def ODE_2(X, t):
    dXdt = [X[1], -(w0**2)*X[0]]
    return dXdt

# Nonlinear Pendulum Solution
solution = torch.from_numpy(odeint(ODE, X0, t.numpy().flatten())).view(-1,2)
x1       = solution[:,0]
x2       = solution[:,1]
x1_max   = torch.abs(x1).max().item()
x2_max   = torch.abs(x2).max().item()

# Harmonic Oscillator Solution
solution2 = torch.from_numpy(odeint(ODE_2, X0, t.numpy().flatten())).view(-1,2)
y1        = solution2[:,0]
y2        = solution2[:,1]
y1_max    = torch.abs(x1).max().item()
y2_max    = torch.abs(x2).max().item()

# solution.dtype = np.double

# Pick points for training
N_training = 40
t_data     = torch.linspace(ti, tf*0.3, N_training).view(-1,1)
training_data = solution[torch.searchsorted(t.flatten(), t_data.flatten()), :]
x1_data       = training_data[:,0].view(-1,1)
x2_data       = training_data[:,1].view(-1,1)

# Pick a few points for validation
N_validation = 200
t_val        = torch.linspace(ti*1.1, tf, N_validation).view(-1,1)
validation_data = solution[torch.searchsorted(t.flatten(), t_val.flatten()), :]
x1_val          = validation_data[:,0].view(-1,1)
x2_val          = validation_data[:,1].view(-1,1)

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(t, x1, label='NP solution', color='blue', zorder=1)
ax.plot(t, y1, label="SHO Solution", color='green', zorder=2)
ax.scatter(t_data, x1_data, color='red', label='Training Data', s=10, zorder=3)
ax.set_xlabel('t')
ax.set_ylabel('x(t)')
plt.legend(ncol=3, bbox_to_anchor=(0.9, 1.1))
plt.grid()
plt.show()

# %% [markdown]
# ## PINN

# %%
def plot_result():
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
    
    axes[0].grid()
    axes[0].plot(t, x1, color="black", linewidth=2, alpha=1,linestyle='--',label="Nonlinear Pendulum", zorder=0)
    axes[0].plot(t, p, color="blue", linewidth=2, alpha=0.8, label="PINN prediction", zorder=1)
    axes[0].scatter(t_data, x1_data, s=15, color="red", alpha=0.4, label='Training data', zorder=2)
    axes[0].scatter(t_physics.detach(), -0*torch.ones_like(t_physics.detach()), s=10, color="green", alpha=0.4,label='Collocation points', zorder=2)
    axes[0].set_ylim(-1.05*x1_max, 1.05*x1_max)
    axes[0].set_ylabel('x(t)',fontsize="x-large")
    axes[0].set_xlabel('t',fontsize="x-large")
    axes[0].legend()
    
    # axes[1].grid()
    # axes[1].plot(training_loss_history, label='Training Loss', color='red', linewidth=2, zorder=1)
    # # axes[1].plot(validation_loss_history, label='Validation Loss', color='blue', linewidth=1.5, zorder=2, alpha=0.6)
    # axes[1].plot(error_history, label='MSE', color='green', linewidth=2, zorder=3, alpha=0.5)
    # axes[1].set_yscale('log')
    # axes[1].set_xlim(0, epochs)
    # axes[1].set_ylim(1e-7, 1e2)
    # axes[1].set_xlabel('Epochs', fontsize="x-large")
    # axes[1].set_ylabel('Loss', fontsize="x-large")
    # axes[1].set_title(f'MSE = {error:.3e}', fontsize="x-large")
    # axes[1].legend()
    
    fig.suptitle(f"Epoch {i}", fontsize="x-large")

    plt.tight_layout()
    plt.axis("on")

# %%
# Define Neural Network Structure

class FCN(nn.Module):
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        
        self.scale = lambda t: (t - ti)/(tf - ti)
        self.fcs   = nn.Sequential(*[nn.Linear(N_INPUT, N_HIDDEN),activation()])
        self.fch   = nn.Sequential(*[nn.Sequential(*[nn.Linear(N_HIDDEN, N_HIDDEN), activation()]) for _ in range(N_LAYERS-1)])
        self.fce   = nn.Linear(N_HIDDEN, N_OUTPUT)
        
    def forward(self, x):
        x = self.scale(x)
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x

# %%
learning_rate = 5e-2
gamma         = 0.85
epochs        = 50_000 + 1
w_data        = 1
w_derivative  = 0.5
w_ode         = 1e-1
w_energy      = 0
N_phys        = 200

N_layers = 3
N_nodes  = 32

def error(y, x):
    return torch.mean((y - x)**2)/torch.mean(x**2)

# %%
# Define the samle locations for training data
t_training  = t_data.clone().requires_grad_(True)

# Define the sample locations for validation
t_validation = t_val.clone().requires_grad_(True)

# Define the sample locations for physics-informed training
t_physics = torch.linspace(ti, tf, N_phys).view(-1,1).requires_grad_(True)

# %%
# PINN
PINN = FCN(1, 1, N_nodes, N_layers)

# Uses the Adam optimizer
optimizer = torch.optim.Adam(PINN.parameters(), lr = learning_rate)

scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)

# Number of training steps
error_history           = []
training_loss_history   = []
validation_loss_history = []

for i in range(epochs):
    # ===
    # Training
    # ===
    
    PINN.train()
    optimizer.zero_grad()
    
    # Compute data loss .........................
    y  = PINN(t_training)
    data_loss = error(y, x1_data)
    
    # Compute derivative loss .........................
    dy = torch.autograd.grad(y, t_training, torch.ones_like(y), create_graph=True)[0]
    derivative_loss = error(dy, x2_data)
    
    # Compute the ODE loss .........................
    z   = PINN(t_physics)
    dz  = torch.autograd.grad(z, t_physics, torch.ones_like(z), create_graph=True)[0]
    d2z = torch.autograd.grad(dz, t_physics, torch.ones_like(dz), create_graph=True)[0]
    ode_loss = error(d2z, -(w0**2)*z)
    
    # Compute total loss
    loss = w_data*data_loss + w_derivative*derivative_loss + w_ode*ode_loss
    
    # Backpropagate the loss and update weights
    if (i+1) % 1000 == 0: scheduler.step() 
    loss.backward()
    optimizer.step()
    
    # ===
    # Validation
    # ===
    PINN.eval()

    v = PINN(t_validation)
    dv = torch.autograd.grad(v, t_validation, torch.ones_like(v), create_graph=True)[0]
    d2v = torch.autograd.grad(dv, t_validation, torch.ones_like(dv), create_graph=True)[0]
    
    data_loss_val       = torch.sqrt(torch.mean((v - x1_val)**2))
    derivative_loss_val = torch.sqrt(torch.mean((dv - x2_val)**2))
    ode_loss_val        = torch.sqrt(torch.mean((d2v + (w0**2)*x1_val)**2))

    loss_val = w_data*data_loss_val + w_derivative*derivative_loss_val + w_ode*ode_loss_val
    # ===
    # Saving training information
    # ===
    
    error_history.append(error)
    training_loss_history.append(loss.item())
    validation_loss_history.append(loss_val.item())
    
    p   = PINN(t).detach()
    err = error(p, x1.view(-1,1))
    error_history.append(err.item())
    
    # ===
    # Plotting
    # ===
    
    if (i % 100) == 0:
        print(f"Epoch {i}: Validation Loss = {loss_val.item():.5e}, Learning rate = {optimizer.param_groups[0]['lr']:.4e}")
        if any([i==epochs-1, i%5000==0, i==1000]):
            plot_result()
            plt.show()
# Out:
# Epoch 0: Validation Loss = 6.44211e+00, Learning rate = 5.0000e-02
# Epoch 100: Validation Loss = 5.11513e+00, Learning rate = 5.0000e-02
# Epoch 200: Validation Loss = 4.20780e+00, Learning rate = 5.0000e-02
# Epoch 300: Validation Loss = 4.00877e+00, Learning rate = 5.0000e-02
# Epoch 400: Validation Loss = 3.85044e+00, Learning rate = 5.0000e-02
# Epoch 500: Validation Loss = 3.82021e+00, Learning rate = 5.0000e-02
# Epoch 600: Validation Loss = 3.80960e+00, Learning rate = 5.0000e-02
# Epoch 700: Validation Loss = 3.56406e+00, Learning rate = 5.0000e-02
# Epoch 800: Validation Loss = 3.40135e+00, Learning rate = 5.0000e-02
# Epoch 900: Validation Loss = 3.35518e+00, Learning rate = 5.0000e-02
# Epoch 1000: Validation Loss = 3.29880e+00, Learning rate = 4.2500e-02
# Epoch 1100: Validation Loss = 3.28122e+00, Learning rate = 4.2500e-02
# Epoch 1200: Validation Loss = 3.26617e+00, Learning rate = 4.2500e-02
# Epoch 1300: Validation Loss = 3.25118e+00, Learning rate = 4.2500e-02
# Epoch 1400: Validation Loss = 3.24373e+00, Learning rate = 4.2500e-02
# Epoch 1500: Validation Loss = 3.21867e+00, Learning rate = 4.2500e-02
# Epoch 1600: Validation Loss = 3.22771e+00, Learning rate = 4.2500e-02
# Epoch 1700: Validation Loss = 3.19724e+00, Learning rate = 4.2500e-02
# Epoch 1800: Validation Loss = 3.22088e+00, Learning rate = 4.2500e-02
# Epoch 1900: Validation Loss = 3.19775e+00, Learning rate = 4.2500e-02
# Epoch 2000: Validation Loss = 2.99853e+00, Learning rate = 3.6125e-02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 51
#      49 v = PINN(t_validation)
#      50 dv = torch.autograd.grad(v, t_validation, torch.ones_like(v), create_graph=True)[0]
# ---> 51 d2v = torch.autograd.grad(dv, t_validation, torch.ones_like(dv), create_graph=True)[0]
#      53 data_loss_val       = torch.sqrt(torch.mean((v - x1_val)**2))
#      54 derivative_loss_val = torch.sqrt(torch.mean((dv - x2_val)**2))
#
# File ~/Documents/PINNs/.PINNs/lib/python3.11/site-packages/torch/autograd/__init__.py:411, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     407     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     408         grad_outputs_
#     409     )
#     410 else:
# --> 411     result = Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     412         t_outputs,
#     413         grad_outputs_,
#     414         retain_graph,
#     415         create_graph,
#     416         inputs,
#     417         allow_unused,
#     418         accumulate_grad=False,
#     419     )  # Calls into the C++ engine to run the backward pass
#     420 if materialize_grads:
#     421     if any(
#     422         result[i] is None and not is_tensor_like(inputs[i])
#     423         for i in range(len(inputs))
#     424     ):
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(figsize=(14, 8))
M = 10
n = len(data_validation_loss_history[0:-1:M])
if w_data > 0:
    ax.plot(range(n), data_validation_loss_history[0:-1:M], label='Validation Data Loss', color='red', linewidth=2, zorder=2, alpha=0.7)
if w_derivative > 0:
    ax.plot(range(n), derivative_validation_loss_history[0:-1:M], label='Validation Derivative Data Loss', color='blue', linewidth=2, zorder=2, alpha=0.7)
if w_ode > 0:
    ax.plot(range(n), ode_validation_loss_history[0:-1:M], label='Validation Physics Data Loss', color='green', linewidth=2, zorder=2, alpha=0.7)

    
ax.plot(range(n), validation_loss_history[0:-1:M], label='Validation Total Loss', color='purple', linewidth=2, zorder=2, alpha=0.7)
ax.plot(range(n), error_history[0:-1:M], label='MSE', color='black', linewidth=1, zorder=5, alpha=1)
ax.set_xlabel('Epochs', fontsize="x-large")
ax.legend()
ax.grid()
ax.set_yscale('log')
ax.set_title('Validation Losses', fontsize="x-large")
ax.set_ylim(1e-7, 1e3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 8))
M = 200
n = len(data_loss_history[0:-1:M])
if w_data > 0:
    ax.plot(range(n), data_loss_history[0:-1:M], label='Training Data Loss', color='red', linewidth=2, zorder=2, alpha=0.7)
if w_derivative > 0:
    ax.plot(range(n), derivative_loss_history[0:-1:M], label='Training Derivative Data Loss', color='blue', linewidth=2, zorder=2, alpha=0.7)
if w_ode > 0:
    ax.plot(range(n), ode_loss_history[0:-1:M], label='Training Physics Data Loss', color='green', linewidth=2, zorder=2, alpha=0.7)

ax.plot(range(n), loss_history[0:-1:M], label='Training Total Loss', color='purple', linewidth=2, zorder=2, alpha=0.7)

ax.set_xlabel('Epochs', fontsize="x-large")
ax.legend()
ax.grid()
ax.set_yscale('log')
ax.set_title('Training Losses', fontsize="x-large")
plt.show()

# %%
MSE_data = np.array(error_history)
np.save(f"data/error_SHO_ODE_NP_DATA_{X0[0]:.3f}.npy", MSE_data)

# %%
plot_result(
            i, epochs, t.detach(), x1.detach(), y1.detach(),
            t_data.detach(), x1_data.detach(),
            p, t_physics.detach(),
            data_loss_history, data_validation_loss_history, error_history
        )

plt.savefig("no_period_learning.png")
